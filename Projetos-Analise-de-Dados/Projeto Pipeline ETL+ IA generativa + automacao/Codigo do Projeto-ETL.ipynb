# %% [markdown]
# ![LogoBootcampSantander](https://lp.dio.me/wp-content/uploads/2023/05/BADGE_LUZ-4.png)
# # Santander Bootcamp 2023 - Ciência de Dados com Python (Projeto ETL com Python)

# %% [markdown]
# **Contexto:** Você é um cientista de dados no Santander e recebeu a tarefa de envolver seus clientes de maneira mais personalizada. Seu objetivo é usar o poder da IA Generativa para criar mensagens de marketing personalizadas que serão entregues a cada cliente.
#
# **Condições do Problema:**
#
# 1. Você recebeu uma planilha simples, em formato CSV ('SDW2023.csv'), com uma lista de IDs de usuário do banco com a seguinte estrutura:
#   ```
#   UserID
#   1
#   2
#   3
#   4
#   5
#   ```
# 2. Seu trabalho é consumir o endpoint `GET https://sdw-2023-prd.up.railway.app/users/{id}` (API da Santander Dev Week 2023) para obter os dados de cada cliente.
#
#
# 3. Depois de obter os dados dos clientes, você vai usar a API de alguma IA generativa, como por exemplo: ChatGPT (OpenAI), Bard(google), Bing(microsoft) para gerar uma mensagem de marketing personalizada para cada cliente. Essa mensagem deve enfatizar a importância dos investimentos.

# %% [markdown]
# ## Extract(Extração)
# - Puxando as informações da api do santander dev week 2023.

# %%
# Repositório da API: https://github.com/digitalinnovationone/santander-dev-week-2023-api
sdw2023_api_url = 'https://sdw-2023-prd.up.railway.app'

# %%
import pandas as pd

df = pd.read_csv('SDW2023.csv')
user_ids = df['UserID'].tolist()
print(user_ids)
# Out:
# [1, 14, 15, 21, 29, 31, 32, 33, 36, 40, 45, 70, 85, 98]

# %%
import requests
import json

def get_user(id):
  response = requests.get(f'{sdw2023_api_url}/users/{id}')
  return response.json() if response.status_code == 200 else None

users = [user for id in user_ids if (user := get_user(id)) is not None]
print(json.dumps(users, indent=2))
# Out:
# [
#   {
#     "id": 1,
#     "name": "Devweekerson",
#     "account": {
#       "id": 1,
#       "number": "01.097954-4",
#       "agency": "2030",
#       "balance": 624.12,
#       "limit": 1000.0
#     },
#     "card": {
#       "id": 1,
#       "number": "xxxx xxxx xxxx 1111",
#       "limit": 2000.0
#     },
#     "features": [
#       {
#         "id": 2,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/pay.svg",
#         "description": "Pagar"
#       },
#       {
#         "id": 3,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/transfer.svg",
#         "description": "Transferir"
#       },
#       {
#         "id": 4,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/account.svg",
#         "description": "Conta Corrente"
#       },
#       {
#         "id": 5,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/cards.svg",
#         "description": "Cart\u00f5es"
#       },
#       {
#         "id": 1,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/pix.svg",
#         "description": "PIX"
#       }
#     ],
#     "news": [
#       {
#         "id": 1,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "O Santander tem solu\u00e7\u00f5es de cr\u00e9dito sob medida pra voc\u00ea. Confira!"
#       },
#       {
#         "id": 2,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/insurance.svg",
#         "description": "Santander Seguro Casa, seu faz-tudo. Mais de 50 servi\u00e7os pra voc\u00ea. Confira!"
#       }
#     ]
#   },
#   {
#     "id": 14,
#     "name": "Maria",
#     "account": {
#       "id": 21,
#       "number": "00110-2",
#       "agency": "2003",
#       "balance": 500.0,
#       "limit": 1000.0
#     },
#     "card": {
#       "id": 14,
#       "number": "**** **** **** 0322",
#       "limit": 500.0
#     },
#     "features": [
#       {
#         "id": 11,
#         "icon": "string",
#         "description": "string"
#       }
#     ],
#     "news": [
#       {
#         "id": 25,
#         "icon": "string",
#         "description": "string"
#       },
#       {
#         "id": 252,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 253,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 972,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Maria, todavia, o novo modelo estrutural aqui preconizado agrega valor ao estabelecimento do levantamento das vari\u00e1veis envolvidas. "
#       },
#       {
#         "id": 1597,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Maria, planeje hoje, invista para sempre."
#       },
#       {
#         "id": 1598,
#         "icon": "money-mouth-face.svg",
#         "description": "Maria, investir hoje, colher amanh\u00e3."
#       },
#       {
#         "id": 1599,
#         "icon": "money-mouth-face.svg",
#         "description": "Maria, seguran\u00e7a financeira via investimentos."
#       },
#       {
#         "id": 1600,
#         "icon": "money-mouth-face.svg",
#         "description": "Maria, invista agora no seu amanh\u00e3."
#       },
#       {
#         "id": 1601,
#         "icon": "money-mouth-face.svg",
#         "description": "Maria, investimentos: seu passaporte para o sucesso."
#       },
#       {
#         "id": 1891,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Obrigado, Maria, por investir conosco! \ud83d\udc99"
#       },
#       {
#         "id": 2019,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "D\u00ea asas \u00e0s suas futuras conquistas com investimentos estrat\u00e9gicos. #SeuFuturoFinanceiro"
#       },
#       {
#         "id": 2025,
#         "icon": "None",
#         "description": "1. Remo\u00e7\u00e3o do detonador com pin\u00e7a. \n2. Neutraliza\u00e7\u00e3o do explosivo com \u00e1gua. \n3. Corte do fio de ativa\u00e7\u00e3o com tesoura. \n4. Desativa\u00e7\u00e3o controlada com rob\u00f4 especializado. \n5. Uso de explosivo contra explosivo (contra-carga)."
#       },
#       {
#         "id": 2215,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Investir \u00e9 garantir um futuro financeiro seguro, Maria!"
#       },
#       {
#         "id": 2216,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Ol\u00e1 Maria! Fa\u00e7a seu dinheiro trabalhar por voc\u00ea. Invista agora para um futuro financeiro seguro!"
#       },
#       {
#         "id": 2224,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Invista no seu futuro e garanta sua estabilidade financeira!"
#       }
#     ]
#   },
#   {
#     "id": 15,
#     "name": "Pyterson",
#     "account": {
#       "id": 22,
#       "number": "0001-1",
#       "agency": "0001",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 15,
#       "number": "1234 1234 1234 1111",
#       "limit": 1000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 51,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Invista hoje, colha amanh\u00e3! #FuturoBrilhante"
#       },
#       {
#         "id": 132,
#         "icon": "\ud83e\udd11",
#         "description": null
#       },
#       {
#         "id": 140,
#         "icon": "\ud83e\udd11",
#         "description": null
#       },
#       {
#         "id": 148,
#         "icon": "\ud83e\udd11",
#         "description": "Pyterson, O futuro \u00e9 hoje: invista para colher amanh\u00e3."
#       },
#       {
#         "id": 156,
#         "icon": "\ud83e\udd11",
#         "description": "Pyterson, Invista hoje, desfrute no futuro."
#       },
#       {
#         "id": 254,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 255,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 973,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Pyterson, a certifica\u00e7\u00e3o de metodologias que nos auxiliam a lidar com a consulta aos diversos militantes representa uma abertura para a melhoria dos m\u00e9todos utilizados na avalia\u00e7\u00e3o de resultados. "
#       },
#       {
#         "id": 939,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Pyterson, invista em seu futuro com sabedoria. Os investimentos s\u00e3o a chave para alcan\u00e7ar suas metas financeiras. N\u00e3o espere, comece hoje!"
#       },
#       {
#         "id": 1602,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Pyterson, seu futuro depende dos investimentos."
#       },
#       {
#         "id": 1603,
#         "icon": "money-mouth-face.svg",
#         "description": "Pyterson, construa riqueza com investimentos."
#       },
#       {
#         "id": 1604,
#         "icon": "money-mouth-face.svg",
#         "description": "Pyterson, investir \u00e9 cuidar do seu futuro."
#       },
#       {
#         "id": 1605,
#         "icon": "money-mouth-face.svg",
#         "description": "Pyterson, seu futuro depende dos investimentos."
#       },
#       {
#         "id": 1606,
#         "icon": "money-mouth-face.svg",
#         "description": "Pyterson, fa\u00e7a seu dinheiro trabalhar por voc\u00ea."
#       },
#       {
#         "id": 1885,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Invista em seu futuro com sabedoria!"
#       },
#       {
#         "id": 1886,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Invista hoje para um futuro seguro. #PlanejeSeuFuturo"
#       },
#       {
#         "id": 1887,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Obrigado, Pyterson, por escolher o Banco Santander para investir!"
#       },
#       {
#         "id": 1892,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Obrigado, Pyterson, pelo investimento no Santander! \ud83d\ude4f"
#       },
#       {
#         "id": 2020,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Invista agora e construa seu futuro!"
#       },
#       {
#         "id": 2021,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Invista hoje, colha amanh\u00e3!"
#       },
#       {
#         "id": 2098,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "O Santander tem solu\u00e7\u00f5es de cr\u00e9dito sob medida pra voc\u00ea. Confira!"
#       },
#       {
#         "id": 776,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Ol\u00e1 Pyterson, os investimentos s\u00e3o a chave para construir um futuro financeiro s\u00f3lido. Comece hoje a colher frutos amanh\u00e3."
#       }
#     ]
#   },
#   {
#     "id": 21,
#     "name": "Pyterson",
#     "account": {
#       "id": 28,
#       "number": "00012-1",
#       "agency": "0001",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 21,
#       "number": "**** **** **** 3232",
#       "limit": 1000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 266,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 267,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 979,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Pyterson, o que temos que ter sempre em mente \u00e9 que a cont\u00ednua expans\u00e3o de nossa atividade aponta para a melhoria das posturas dos \u00f3rg\u00e3os dirigentes com rela\u00e7\u00e3o \u00e0s suas atribui\u00e7\u00f5es. "
#       },
#       {
#         "id": 1660,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "\"Nossa equipe de especialistas est\u00e1 aqui para ajudar a realizar seus objetivos financeiros. Agende uma consulta hoje mesmo!\""
#       },
#       {
#         "id": 1661,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "\"Acumule pontos a cada transa\u00e7\u00e3o e aproveite benef\u00edcios exclusivos com nosso programa de recompensas.\""
#       },
#       {
#         "id": 1662,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "\"Fa\u00e7a seu dinheiro trabalhar por voc\u00ea. Descubra nossas op\u00e7\u00f5es de investimento hoje mesmo!\""
#       },
#       {
#         "id": 1663,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "\"Simplifique suas transa\u00e7\u00f5es internacionais com nossos servi\u00e7os de c\u00e2mbio e remessas globais.\""
#       },
#       {
#         "id": 1664,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "\"Fa\u00e7a seu dinheiro trabalhar por voc\u00ea. Descubra nossas op\u00e7\u00f5es de investimento hoje mesmo!\""
#       },
#       {
#         "id": 1665,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "\"Esteja sempre informado sobre suas finan\u00e7as. Inscreva-se para receber alertas de saldo e atividade da conta em tempo real.\""
#       },
#       {
#         "id": 1666,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "\"proteja o que \u00e9 importante. Explore nossas op\u00e7\u00f5es de seguros para garantir um futuro seguro para voc\u00ea e sua fam\u00edlia.\""
#       },
#       {
#         "id": 1667,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "sabia que controle financeiro ao alcance das suas m\u00e3os. Baixe nosso app e gerencie suas finan\u00e7as com facilidade."
#       },
#       {
#         "id": 1668,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "acumule pontos a cada transa\u00e7\u00e3o e aproveite benef\u00edcios exclusivos com nosso programa de recompensas."
#       },
#       {
#         "id": 1669,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "sabia que controle financeiro ao alcance das suas m\u00e3os. Baixe nosso app e gerencie suas finan\u00e7as com facilidade."
#       },
#       {
#         "id": 1704,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "sabia que controle financeiro ao alcance das suas m\u00e3os. Baixe nosso app e gerencie suas finan\u00e7as com facilidade."
#       },
#       {
#         "id": 1705,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "acumule pontos a cada transa\u00e7\u00e3o e aproveite benef\u00edcios exclusivos com nosso programa de recompensas."
#       },
#       {
#         "id": 1706,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "fa\u00e7a seu dinheiro trabalhar por voc\u00ea. Descubra nossas op\u00e7\u00f5es de investimento hoje mesmo!"
#       },
#       {
#         "id": 1707,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "simplifique suas transa\u00e7\u00f5es internacionais com nossos servi\u00e7os de c\u00e2mbio e remessas globais."
#       },
#       {
#         "id": 1708,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "proteja o que \u00e9 importante. Explore nossas op\u00e7\u00f5es de seguros para garantir um futuro seguro para voc\u00ea e sua fam\u00edlia."
#       },
#       {
#         "id": 2099,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "O Santander tem solu\u00e7\u00f5es de cr\u00e9dito sob medida pra voc\u00ea. Confira!"
#       },
#       {
#         "id": 783,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Pyterson, investir \u00e9 construir seu futuro financeiro. N\u00e3o deixe o tempo passar, comece hoje mesmo a colher os frutos do amanh\u00e3!"
#       }
#     ]
#   },
#   {
#     "id": 29,
#     "name": "Faust\u00e3o",
#     "account": {
#       "id": 36,
#       "number": "100000-09",
#       "agency": "0007",
#       "balance": 4000.0,
#       "limit": 10000.0
#     },
#     "card": {
#       "id": 29,
#       "number": "**** **** **** 9999",
#       "limit": 10000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 172,
#         "icon": null,
#         "description": "Ol\u00e1, Faust\u00e3o!Invista seu dinheiro e alcance seus objetivos. Converse com um especialista em investimentos hoje."
#       },
#       {
#         "id": 280,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 281,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 986,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Faust\u00e3o, a certifica\u00e7\u00e3o de metodologias que nos auxiliam a lidar com o acompanhamento das prefer\u00eancias de consumo cumpre um papel essencial na formula\u00e7\u00e3o dos procedimentos normalmente adotados. "
#       }
#     ]
#   },
#   {
#     "id": 31,
#     "name": "Deyla",
#     "account": {
#       "id": 38,
#       "number": "20002-2",
#       "agency": "0001",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 31,
#       "number": "2222 **** **** 2222",
#       "limit": 1000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 43,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Invista para um futuro mais seguro e pr\u00f3spero!"
#       },
#       {
#         "id": 284,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 285,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 988,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Deyla, todas estas quest\u00f5es, devidamente ponderadas, levantam d\u00favidas sobre se a crescente influ\u00eancia da m\u00eddia \u00e9 uma das consequ\u00eancias das novas proposi\u00e7\u00f5es. "
#       }
#     ]
#   },
#   {
#     "id": 32,
#     "name": "Thanos",
#     "account": {
#       "id": 39,
#       "number": "30003-3",
#       "agency": "0001",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 32,
#       "number": "3333 **** **** 3333",
#       "limit": 1000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 44,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Thanos, os investimentos fazem seu futuro florescer. #PensandoAl\u00e9mDoEstalarDeDedos"
#       },
#       {
#         "id": 286,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 287,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 989,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Thanos, a n\u00edvel organizacional, a crescente influ\u00eancia da m\u00eddia nos obriga \u00e0 an\u00e1lise das dire\u00e7\u00f5es preferenciais no sentido do progresso. "
#       },
#       {
#         "id": 2371,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Thanos, otimize seu poder financeiro: invista sabiamente para garantir um futuro pr\u00f3spero. O universo dos investimentos aguarda!"
#       }
#     ]
#   },
#   {
#     "id": 33,
#     "name": "Ada Shelby",
#     "account": {
#       "id": 40,
#       "number": "0004-4",
#       "agency": "004",
#       "balance": 0.0,
#       "limit": 400.0
#     },
#     "card": {
#       "id": 33,
#       "number": "**** **** **** 4444",
#       "limit": 4000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 288,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 289,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 990,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Ada Shelby, por outro lado, o julgamento imparcial das eventualidades estende o alcance e a import\u00e2ncia dos modos de opera\u00e7\u00e3o convencionais. "
#       }
#     ]
#   },
#   {
#     "id": 36,
#     "name": "jason",
#     "account": {
#       "id": 43,
#       "number": "0010-1",
#       "agency": "2212",
#       "balance": 0.0,
#       "limit": 12.0
#     },
#     "card": {
#       "id": 36,
#       "number": "**** **** **** 5005",
#       "limit": 100.0
#     },
#     "features": [
#       {
#         "id": 15,
#         "icon": "string",
#         "description": "string"
#       }
#     ],
#     "news": [
#       {
#         "id": 294,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 295,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 993,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "jason, pensando mais a longo prazo, a ado\u00e7\u00e3o de pol\u00edticas descentralizadoras acarreta um processo de reformula\u00e7\u00e3o e moderniza\u00e7\u00e3o do levantamento das vari\u00e1veis envolvidas. "
#       },
#       {
#         "id": 45,
#         "icon": "string",
#         "description": "string"
#       }
#     ]
#   },
#   {
#     "id": 40,
#     "name": "Mary",
#     "account": {
#       "id": 47,
#       "number": "0000-1",
#       "agency": "0001",
#       "balance": 0.0,
#       "limit": 0.0
#     },
#     "card": {
#       "id": 40,
#       "number": "**** **** **** 2424",
#       "limit": 1000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 302,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 303,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 997,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Mary, assim mesmo, o julgamento imparcial das eventualidades aponta para a melhoria das regras de conduta normativas. "
#       },
#       {
#         "id": 922,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Ol\u00e1 Mary, invista em seu futuro com sabedoria. Os investimentos s\u00e3o a chave para conquistar seus objetivos financeiros."
#       },
#       {
#         "id": 886,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Mary, investir \u00e9 pavimentar seu caminho para um futuro financeiro seguro e pr\u00f3spero. N\u00e3o deixe o amanh\u00e3 esperar, comece hoje!"
#       },
#       {
#         "id": 418,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Mary, invista em seu futuro financeiro hoje para colher frutos amanh\u00e3. N\u00e3o deixe o tempo passar. Comece a investir agora."
#       },
#       {
#         "id": 2372,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Ol\u00e1 Mary, potencialize seu futuro financeiro com investimentos s\u00f3lidos. Eles s\u00e3o a chave para conquistar seus objetivos. Comece hoje!"
#       }
#     ]
#   },
#   {
#     "id": 45,
#     "name": "Jaspion",
#     "account": {
#       "id": 52,
#       "number": "0003",
#       "agency": "1221",
#       "balance": 0.0,
#       "limit": 0.0
#     },
#     "card": {
#       "id": 45,
#       "number": "*** **** **** 0003",
#       "limit": 1000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 312,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 313,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 1002,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Jaspion, o empenho em analisar a necessidade de renova\u00e7\u00e3o processual afeta positivamente a correta previs\u00e3o das condi\u00e7\u00f5es inegavelmente apropriadas. "
#       }
#     ]
#   },
#   {
#     "id": 70,
#     "name": "Xico",
#     "account": {
#       "id": 77,
#       "number": "74196-5",
#       "agency": "4196",
#       "balance": 0.0,
#       "limit": 99999.0
#     },
#     "card": {
#       "id": 70,
#       "number": "**** **** **** 1881",
#       "limit": 8000.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 362,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 363,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 1027,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Xico, ainda assim, existem d\u00favidas a respeito de como a mobilidade dos capitais internacionais pode nos levar a considerar a reestrutura\u00e7\u00e3o dos modos de opera\u00e7\u00e3o convencionais. "
#       },
#       {
#         "id": 773,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Xico, investir \u00e9 construir seu amanh\u00e3 com intelig\u00eancia. N\u00e3o deixe o tempo passar, comece hoje a garantir seu futuro financeiro!"
#       }
#     ]
#   },
#   {
#     "id": 85,
#     "name": "Vitor Fontenle2",
#     "account": {
#       "id": 92,
#       "number": "1254665",
#       "agency": "0216465",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 84,
#       "number": "1564 4758 4425 2555",
#       "limit": 1000.0
#     },
#     "features": [
#       {
#         "id": 42,
#         "icon": "string",
#         "description": "string"
#       }
#     ],
#     "news": [
#       {
#         "id": 82,
#         "icon": "string",
#         "description": "string"
#       },
#       {
#         "id": 390,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 391,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 1041,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Vitor Fontenle2, por outro lado, a percep\u00e7\u00e3o das dificuldades pode nos levar a considerar a reestrutura\u00e7\u00e3o do investimento em reciclagem t\u00e9cnica. "
#       },
#       {
#         "id": 909,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Vitor Fontenle2, invista em seu futuro financeiro! Os investimentos s\u00e3o o caminho para conquistar suas metas. Comece hoje!"
#       }
#     ]
#   },
#   {
#     "id": 98,
#     "name": "Camylle",
#     "account": {
#       "id": 105,
#       "number": "00001-17",
#       "agency": "9999",
#       "balance": 0.0,
#       "limit": 420.0
#     },
#     "card": {
#       "id": 97,
#       "number": "**** **** **** 1127",
#       "limit": 270.0
#     },
#     "features": [],
#     "news": [
#       {
#         "id": 797,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Camylle, invista no seu futuro financeiro com sabedoria. Os investimentos s\u00e3o a chave para conquistar seus objetivos."
#       },
#       {
#         "id": 416,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 417,
#         "icon": "https://images.genius.com/31fac7e2bef0ff83f25dbd8077863794.1000x1000x1.jpg",
#         "description": "Eduardo esteve aqui"
#       },
#       {
#         "id": 1054,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": "Camylle, todas estas quest\u00f5es, devidamente ponderadas, levantam d\u00favidas sobre se a hegemonia do ambiente pol\u00edtico possibilita uma melhor vis\u00e3o global das posturas dos \u00f3rg\u00e3os dirigentes com rela\u00e7\u00e3o \u00e0s suas atribui\u00e7\u00f5es. "
#       }
#     ]
#   }
# ]

# %% [markdown]
# ## Transform(Transformação)
# * Irei utilizar a biblioteca pyautogui de automação para ao invés de consumir créditos da api do chat gpt diretamente, o código ir direto no chat do chatgpt e extrair as respostas dele para depois voltar com a resposta personalizada para o usuário.
# * Obviamente é mais simples, rápido e fácil consumir as informações da api do chatgpt, porém essa é uma alernativa para quem não quer pagar ou não tem condições de pagar a api do chat gpt e ainda assim, deseja usar um ia genérica para personalizar as respostas para cada cliente, para o cenário, uma novidade para o cliente;

# %%
# Para quem já usou alguma vez a biblioteca pyautogui, é só importar, quem nunca usou, é necessário instalar
# Para instalar, basta rodar esse código abaixo:
#!pip install pyautogui 
# Vamos precisar de algumas bibliotecas extras para capturar conteúdo da área de transferência
#!pip install pyperclip 
#!pip install keyboard

# %%
import pyautogui as pa
import time
import pyperclip 
import keyboard
import random
# Levando em consideração que você já possui conta para utilizar o chatgpt grátis, esta logado e com o navegador aberto

def coletar_mensagem_personalizada(user):
    pa.PAUSE = 3 
    
    # Entrar no chatgpt, importante já esta logado antes de rodar a aplicação;
    pa.hotkey('ctrl', 't')
    pa.write('https://chat.openai.com/')
    pa.press('enter')
    
    #Comando de prompt
    pa.write(f'Voce eh um especialista em marketing bancario. Crie uma mensagem personalizada para {user["name"]}, falando sobre a importancia dos investimentos.(maximo de 150 caracteres e nao inserir emojis.)')
    pa.press('enter')
    time.sleep(2)
    
    # Copiar a mensagem retornada pelo chatgpt
    pa.click(x=1159, y=334, clicks = 1)
    pa.hotkey('ctrl','v')
    time.sleep(1)
    copied_text = pyperclip.paste()
    mensagem_copiada = copied_text
    
    #Fechar o chatgpt
    pa.click(x=236, y=213, clicks = 1)
    pa.press('enter')
    pa.hotkey('ctrl','w')
    
    return mensagem_copiada.replace('"',"")


# Preenchendo a mensagem personalizada para cada usuário;
for user in users:
    news = coletar_mensagem_personalizada(user)
    print(news,'\n')
    user['news'].append({"id":random.randint(1, 999),
                         "icon":r"https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
                        "description":news})
# Out:
# Devweekerson, invista no seu futuro financeiro hoje mesmo! Os investimentos são o caminho para conquistar seus objetivos. Consulte-nos agora.
#
# Olá Maria, invista no seu futuro hoje para colher benefícios amanhã. Os investimentos são a chave para alcançar seus objetivos financeiros.
#
# Pyterson, investir é o caminho para construir um futuro financeiro sólido. Não deixe o tempo passar, comece hoje mesmo!
#
# Pyterson, investir é construir seu futuro financeiro. Prepare-se hoje para colher conquistas amanhã. Conte conosco nessa jornada.
#
# Fausto, invista em seu futuro financeiro hoje para colher benefícios amanhã. Não adie seu sucesso. Conte conosco para orientá-lo. - Seu time de especialistas em investimentos.
#
# Deyla, invista em seu futuro com sabedoria. Os investimentos são a chave para alcançar seus objetivos financeiros. Contem conosco!
#
# Thanos, equilíbrio é fundamental, também nos investimentos. Diversifique e garanta um futuro próspero.
#
# Ada Shelby, invista em seu futuro com sabedoria. Os investimentos são a chave para conquistar seus sonhos. Conte conosco para guiar seu caminho financeiro.
#
# Olá Jason, potencialize seu futuro financeiro com investimentos inteligentes. Cada passo conta!

# %%
# Pegando a posição do mouse
time.sleep(5)
print(pa.position())
# Out:
# Point(x=236, y=213)

# %% [markdown]
# ## Load(carregar)
#
# * Aqui, o objetivo é carregar as informações de news personalizadas de volta para API do Santander para cada usuário.

# %%
# Vamos atualizar as informações de usuário na api, utilizando o método PUT
def atualizar_user(user):
    response = requests.put(f"{sdw2023_api_url}/users/{user['id']}", json = user).status_code
    return True if response == 200 else False

for user in users:
    success = atualizar_user(user)
    if success == True:
        print(f'As informações do usuário: {user["name"]}, foram atualizadas? {success}')
        
# Algumas informações não foram atualizadas, provavelmente pela conexão com a API ou algum padrão diferente de informações colocadas
# pelos usuários;
# Out:
# As informações do usuário: Pyterson, foram atualizadas? True
# As informações do usuário: jason, foram atualizadas? True
# As informações do usuário: Vitor Fontenle2, foram atualizadas? True
# As informações do usuário: Camylle, foram atualizadas? True
