# %% [markdown]
# # Projeto: Ler, coletar e exportar informações importantes de arquivo xml - Nota Fiscal.
#
# ### Objetivos:
# * Ler arquivo de nota fiscal em xml utilizando python;
# * Padrões das notas fiscais utilizadas: DANFE, Nota carioca(padrão município);
# * Extrair informações importantes como tipo da nota fiscal, se é produto ou serviço, valor, cpnj/cpf do comprador, produtos, serviços prestados;
# * Criar funções para facilitar a leitura e identificação dos outros arquivos xml de nota fiscal que estão na mesma pasta;
# * Colocar essas informações em um dataframe e exportar para excel;
#
# #### Informações importantes:
# * A IDE utilizada foi o **Jupyter Notebook**;
# * Os arquivos se encontram na mesma pasta onde o código foi realizado, caso os arquivos estejam em outra pasta, é necessário adaptar o código para passar o caminho completo dos arquivos;

# %% [markdown]
# ### Importar as bibliotecas que serão utilizadas:

# %%
# Caso não possua a biblioteca abaixo, instale.
#!pip install xmltodict

# %%
import xmltodict #Biblioteca que transforma arquivo xml para dicionário;
import pandas as pd
import os 
import pprint

# %%
#Abrir a nota fiscal e ler
with open('NFs Finais/DANFEBrota.xml', 'rb') as arquivo:
    documento = xmltodict.parse(arquivo)

pprint.pprint(documento) #Consegue visualizar as informações contidas em um dicionário em forma de estrutura de árvore
# Out:
# {'nfeProc': {'@versao': '4.00',
#              '@xmlns': 'http://www.portalfiscal.inf.br/nfe',
#              'NFe': {'@xmlns': 'http://www.portalfiscal.inf.br/nfe',
#                      'Signature': {'@xmlns': 'http://www.w3.org/2000/09/xmldsig#',
#                                    'KeyInfo': {'X509Data': {'X509Certificate': '...'}},
#                                    'SignatureValue': '',
#                                    'SignedInfo': {'CanonicalizationMethod': {'@Algorithm': 'http://www.w3.org/TR/2001/REC-xml-c14n-20010315'},
#                                                   'Reference': {'@URI': '#NFe3521000002195000279550010000028561543252336',
#                                                                 'DigestMethod': {'@Algorithm': 'http://www.w3.org/2000/09/xmldsig#sha1'},
#                                                                 'DigestValue': 'YmPqwgaLfaaaMaafu3L8rLNhtAI=',
#                                                                 'Transforms': {'Transform': [{'@Algorithm': 'http://www.w3.org/2000/09/xmldsig#enveloped-signature'},
#                                                                                              {'@Algorithm': 'http://www.w3.org/TR/2001/REC-xml-c14n-20010315'}]}},
#                                                   'SignatureMethod': {'@Algorithm': 'http://www.w3.org/2000/09/xmldsig#rsa-sha1'}}},
#                      'infNFe': {'@Id': 'NFe35211136882195000279550010000028500052336',
#                                 '@versao': '4.00',
#                                 'cobr': {'dup': {'dVenc': '2021-11-04',
#                                                  'nDup': '001',
#                                                  'vDup': '374.17'},
#                                          'fat': {'nFat': '002856',
#                                                  'vDesc': '0',
#                                                  'vLiq': '374.17',
#                                                  'vOrig': '374.17'}},
#                                 'compra': {'xPed': '2871'},
#                                 'dest': {'CPF': '10000000000',
#                                          'email': 'liradoidonoespaco@gmail.com',
#                                          'enderDest': {'CEP': '22000000',
#                                                        'UF': 'RJ',
#                                                        'cMun': '3304557',
#                                                        'cPais': '1058',
#                                                        'fone': '21999999999',
#                                                        'nro': '0',
#                                                        'xBairro': 'Lua',
#                                                        'xCpl': '0',
#                                                        'xLgr': 'Perdido no '
#                                                                'Espaco',
#                                                        'xMun': 'Rio de Janeiro',
#                                                        'xPais': 'Brasil'},
#                                          'indIEDest': '9',
#                                          'xNome': 'Lira da Hashtag'},
#                                 'det': [{'@nItem': '1',
#                                          'imposto': {'COFINS': {'COFINSOutr': {'CST': '49',
#                                                                                'pCOFINS': '0.00',
#                                                                                'vBC': '0.00',
#                                                                                'vCOFINS': '0.00'}},
#                                                      'ICMS': {'ICMSSN102': {'CSOSN': '102',
#                                                                             'orig': '0'}},
#                                                      'IPI': {'IPITrib': {'CST': '99',
#                                                                          'pIPI': '0.00',
#                                                                          'vBC': '324.17',
#                                                                          'vIPI': '0.00'},
#                                                              'cEnq': '999'},
#                                                      'PIS': {'PISOutr': {'CST': '49',
#                                                                          'pPIS': '0.00',
#                                                                          'vBC': '0.00',
#                                                                          'vPIS': '0.00'}},
#                                                      'vTotTrib': '129.46'},
#                                          'prod': {'CFOP': '6102',
#                                                   'NCM': '39269069',
#                                                   'cEAN': 'SEM GTIN',
#                                                   'cEANTrib': 'SEM GTIN',
#                                                   'cProd': 'BXL0120',
#                                                   'indTot': '1',
#                                                   'qCom': '1.0000',
#                                                   'qTrib': '1.0000',
#                                                   'uCom': 'Un',
#                                                   'uTrib': 'Un',
#                                                   'vDesc': '64.98',
#                                                   'vFrete': '0.15',
#                                                   'vProd': '389.00',
#                                                   'vUnCom': '389.00',
#                                                   'vUnTrib': '389.00',
#                                                   'xPed': '2871',
#                                                   'xProd': 'b.box led'}},
#                                         {'@nItem': '2',
#                                          'imposto': {'COFINS': {'COFINSOutr': {'CST': '49',
#                                                                                'pCOFINS': '0.00',
#                                                                                'vBC': '0.00',
#                                                                                'vCOFINS': '0.00'}},
#                                                      'ICMS': {'ICMSSN102': {'CSOSN': '102',
#                                                                             'orig': '0'}},
#                                                      'IPI': {'IPITrib': {'CST': '99',
#                                                                          'pIPI': '0.00',
#                                                                          'vBC': '8.33',
#                                                                          'vIPI': '0.00'},
#                                                              'cEnq': '999'},
#                                                      'PIS': {'PISOutr': {'CST': '49',
#                                                                          'pPIS': '0.00',
#                                                                          'vBC': '0.00',
#                                                                          'vPIS': '0.00'}},
#                                                      'vTotTrib': '3.15'},
#                                          'prod': {'CFOP': '6102',
#                                                   'NCM': '12119090',
#                                                   'cEAN': 'SEM GTIN',
#                                                   'cEANTrib': 'SEM GTIN',
#                                                   'cProd': 'TOM0120',
#                                                   'indTot': '1',
#                                                   'qCom': '1.0000',
#                                                   'qTrib': '1.0000',
#                                                   'uCom': 'Un',
#                                                   'uTrib': 'Un',
#                                                   'vDesc': '1.67',
#                                                   'vProd': '10.00',
#                                                   'vUnCom': '10.00',
#                                                   'vUnTrib': '10.00',
#                                                   'xPed': '2871',
#                                                   'xProd': 'Tomilho Serpilho'}},
#                                         {'@nItem': '3',
#                                          'imposto': {'COFINS': {'COFINSOutr': {'CST': '49',
#                                                                                'pCOFINS': '0.00',
#                                                                                'vBC': '0.00',
#                                                                                'vCOFINS': '0.00'}},
#                                                      'ICMS': {'ICMSSN102': {'CSOSN': '102',
#                                                                             'orig': '0'}},
#                                                      'IPI': {'IPITrib': {'CST': '99',
#                                                                          'pIPI': '0.00',
#                                                                          'vBC': '8.33',
#                                                                          'vIPI': '0.00'},
#                                                              'cEnq': '999'},
#                                                      'PIS': {'PISOutr': {'CST': '49',
#                                                                          'pPIS': '0.00',
#                                                                          'vBC': '0.00',
#                                                                          'vPIS': '0.00'}},
#                                                      'vTotTrib': '3.15'},
#                                          'prod': {'CFOP': '6102',
#                                                   'NCM': '12119090',
#                                                   'cEAN': 'SEM GTIN',
#                                                   'cEANTrib': 'SEM GTIN',
#                                                   'cProd': 'ORE0120',
#                                                   'indTot': '1',
#                                                   'qCom': '1.0000',
#                                                   'qTrib': '1.0000',
#                                                   'uCom': 'Un',
#                                                   'uTrib': 'Un',
#                                                   'vDesc': '1.67',
#                                                   'vProd': '10.00',
#                                                   'vUnCom': '10.00',
#                                                   'vUnTrib': '10.00',
#                                                   'xPed': '2871',
#                                                   'xProd': 'Oregano '
#                                                            'Bravo-Europeu'}},
#                                         {'@nItem': '4',
#                                          'imposto': {'COFINS': {'COFINSOutr': {'CST': '49',
#                                                                                'pCOFINS': '0.00',
#                                                                                'vBC': '0.00',
#                                                                                'vCOFINS': '0.00'}},
#                                                      'ICMS': {'ICMSSN102': {'CSOSN': '102',
#                                                                             'orig': '0'}},
#                                                      'IPI': {'IPITrib': {'CST': '99',
#                                                                          'pIPI': '0.00',
#                                                                          'vBC': '8.33',
#                                                                          'vIPI': '0.00'},
#                                                              'cEnq': '999'},
#                                                      'PIS': {'PISOutr': {'CST': '49',
#                                                                          'pPIS': '0.00',
#                                                                          'vBC': '0.00',
#                                                                          'vPIS': '0.00'}},
#                                                      'vTotTrib': '3.15'},
#                                          'prod': {'CFOP': '6102',
#                                                   'NCM': '12119090',
#                                                   'cEAN': 'SEM GTIN',
#                                                   'cEANTrib': 'SEM GTIN',
#                                                   'cProd': 'MAN0120',
#                                                   'indTot': '1',
#                                                   'qCom': '1.0000',
#                                                   'qTrib': '1.0000',
#                                                   'uCom': 'Un',
#                                                   'uTrib': 'Un',
#                                                   'vDesc': '1.67',
#                                                   'vProd': '10.00',
#                                                   'vUnCom': '10.00',
#                                                   'vUnTrib': '10.00',
#                                                   'xPed': '2871',
#                                                   'xProd': 'Manjericao '
#                                                            'Italiano'}},
#                                         {'@nItem': '5',
#                                          'imposto': {'COFINS': {'COFINSOutr': {'CST': '49',
#                                                                                'pCOFINS': '0.00',
#                                                                                'vBC': '0.00',
#                                                                                'vCOFINS': '0.00'}},
#                                                      'ICMS': {'ICMSSN102': {'CSOSN': '102',
#                                                                             'orig': '0'}},
#                                                      'IPI': {'IPITrib': {'CST': '99',
#                                                                          'pIPI': '0.00',
#                                                                          'vBC': '8.33',
#                                                                          'vIPI': '0.00'},
#                                                              'cEnq': '999'},
#                                                      'PIS': {'PISOutr': {'CST': '49',
#                                                                          'pPIS': '0.00',
#                                                                          'vBC': '0.00',
#                                                                          'vPIS': '0.00'}},
#                                                      'vTotTrib': '3.15'},
#                                          'prod': {'CFOP': '6102',
#                                                   'NCM': '12119090',
#                                                   'cEAN': 'SEM GTIN',
#                                                   'cEANTrib': 'SEM GTIN',
#                                                   'cProd': 'COE0120',
#                                                   'indTot': '1',
#                                                   'qCom': '1.0000',
#                                                   'qTrib': '1.0000',
#                                                   'uCom': 'Un',
#                                                   'uTrib': 'Un',
#                                                   'vDesc': '1.67',
#                                                   'vProd': '10.00',
#                                                   'vUnCom': '10.00',
#                                                   'vUnTrib': '10.00',
#                                                   'xPed': '2871',
#                                                   'xProd': 'Coentro '
#                                                            'Portugues'}},
#                                         {'@nItem': '6',
#                                          'imposto': {'COFINS': {'COFINSOutr': {'CST': '49',
#                                                                                'pCOFINS': '0.00',
#                                                                                'vBC': '0.00',
#                                                                                'vCOFINS': '0.00'}},
#                                                      'ICMS': {'ICMSSN102': {'CSOSN': '102',
#                                                                             'orig': '0'}},
#                                                      'IPI': {'IPITrib': {'CST': '99',
#                                                                          'pIPI': '0.00',
#                                                                          'vBC': '8.33',
#                                                                          'vIPI': '0.00'},
#                                                              'cEnq': '999'},
#                                                      'PIS': {'PISOutr': {'CST': '49',
#                                                                          'pPIS': '0.00',
#                                                                          'vBC': '0.00',
#                                                                          'vPIS': '0.00'}},
#                                                      'vTotTrib': '3.15'},
#                                          'prod': {'CFOP': '6102',
#                                                   'NCM': '12099100',
#                                                   'cEAN': 'SEM GTIN',
#                                                   'cEANTrib': 'SEM GTIN',
#                                                   'cProd': 'SAL0120',
#                                                   'indTot': '1',
#                                                   'qCom': '1.0000',
#                                                   'qTrib': '1.0000',
#                                                   'uCom': 'Un',
#                                                   'uTrib': 'Un',
#                                                   'vDesc': '1.67',
#                                                   'vProd': '10.00',
#                                                   'vUnCom': '10.00',
#                                                   'vUnTrib': '10.00',
#                                                   'xPed': '2871',
#                                                   'xProd': 'Salsa Hortense'}},
#                                         {'@nItem': '7',
#                                          'imposto': {'COFINS': {'COFINSOutr': {'CST': '49',
#                                                                                'pCOFINS': '0.00',
#                                                                                'vBC': '0.00',
#                                                                                'vCOFINS': '0.00'}},
#                                                      'ICMS': {'ICMSSN102': {'CSOSN': '102',
#                                                                             'orig': '0'}},
#                                                      'IPI': {'IPITrib': {'CST': '99',
#                                                                          'pIPI': '0.00',
#                                                                          'vBC': '8.35',
#                                                                          'vIPI': '0.00'},
#                                                              'cEnq': '999'},
#                                                      'PIS': {'PISOutr': {'CST': '49',
#                                                                          'pPIS': '0.00',
#                                                                          'vBC': '0.00',
#                                                                          'vPIS': '0.00'}},
#                                                      'vTotTrib': '3.15'},
#                                          'prod': {'CFOP': '6102',
#                                                   'NCM': '12099100',
#                                                   'cEAN': 'SEM GTIN',
#                                                   'cEANTrib': 'SEM GTIN',
#                                                   'cProd': 'ALF0120',
#                                                   'indTot': '1',
#                                                   'qCom': '1.0000',
#                                                   'qTrib': '1.0000',
#                                                   'uCom': 'Un',
#                                                   'uTrib': 'Un',
#                                                   'vDesc': '1.67',
#                                                   'vFrete': '0.02',
#                                                   'vProd': '10.00',
#                                                   'vUnCom': '10.00',
#                                                   'vUnTrib': '10.00',
#                                                   'xPed': '2871',
#                                                   'xProd': 'Alface '
#                                                            'Baby-Leaf'}}],
#                                 'emit': {'CNPJ': '36882195000279',
#                                          'CRT': '1',
#                                          'IE': '131494646119',
#                                          'enderEmit': {'CEP': '03106010',
#                                                        'UF': 'SP',
#                                                        'cMun': '3550308',
#                                                        'cPais': '1058',
#                                                        'fone': '21970999536',
#                                                        'nro': '035',
#                                                        'xBairro': 'Mooca',
#                                                        'xLgr': 'Rua Dona Ana '
#                                                                'Neri',
#                                                        'xMun': 'Sao Paulo',
#                                                        'xPais': 'Brasil'},
#                                          'xFant': 'Brota Company',
#                                          'xNome': 'BROTA COMPANY COMERCIO DE '
#                                                   'PLANTAS LTDA'},
#                                 'ide': {'cDV': '6',
#                                         'cMunFG': '3550308',
#                                         'cNF': '54325233',
#                                         'cUF': '35',
#                                         'dhEmi': '2021-11-04T10:15:59-03:00',
#                                         'dhSaiEnt': '2021-11-04T10:15:59-03:00',
#                                         'finNFe': '1',
#                                         'idDest': '2',
#                                         'indFinal': '1',
#                                         'indIntermed': '0',
#                                         'indPres': '2',
#                                         'mod': '55',
#                                         'nNF': '26',
#                                         'natOp': 'Venda de mercadorias',
#                                         'procEmi': '0',
#                                         'serie': '1',
#                                         'tpAmb': '1',
#                                         'tpEmis': '1',
#                                         'tpImp': '1',
#                                         'tpNF': '1',
#                                         'verProc': 'Tiny ERP'},
#                                 'infAdic': {'infCpl': 'Tributos aproximados: '
#                                                       'R$ 67,54 (Federal) e R$ '
#                                                       '80,82 (Estadual). '
#                                                       'Fonte: IBPT BA21D5<br '
#                                                       '/>b.Box\n'
#                                                       '                    Led '
#                                                       '- horta inteligente com '
#                                                       'luz de led e irrigacao '
#                                                       'automatica<br />Capsula '
#                                                       '1: Tomilho Serpilho<br\n'
#                                                       '                    '
#                                                       '/>Capsula 2: Oregano '
#                                                       'Bravo-Europeu<br '
#                                                       '/>Capsula 3: Manjericao '
#                                                       'Italiano<br />Capsula\n'
#                                                       '                    4: '
#                                                       'Coentro Portugues<br '
#                                                       '/>Capsula 5: Salsa '
#                                                       'Hortense<br />Capsula '
#                                                       '6: Alface Baby-Leaf<br\n'
#                                                       '                    '
#                                                       '/><br />'},
#                                 'pag': {'detPag': {'tPag': '99',
#                                                    'vPag': '374.17',
#                                                    'xPag': 'Conta a receber'}},
#                                 'total': {'ICMSTot': {'vBC': '0.00',
#                                                       'vBCST': '0.00',
#                                                       'vCOFINS': '0.00',
#                                                       'vDesc': '75.00',
#                                                       'vFCP': '0.00',
#                                                       'vFCPST': '0.00',
#                                                       'vFCPSTRet': '0.00',
#                                                       'vFCPUFDest': '0.00',
#                                                       'vFrete': '0.17',
#                                                       'vICMS': '0.00',
#                                                       'vICMSDeson': '0.00',
#                                                       'vICMSUFDest': '0.00',
#                                                       'vICMSUFRemet': '0.00',
#                                                       'vII': '0.00',
#                                                       'vIPI': '0.00',
#                                                       'vIPIDevol': '0.00',
#                                                       'vNF': '374.17',
#                                                       'vOutro': '0.00',
#                                                       'vPIS': '0.00',
#                                                       'vProd': '449.00',
#                                                       'vST': '0.00',
#                                                       'vSeg': '0.00',
#                                                       'vTotTrib': '148.36'}},
#                                 'transp': {'modFrete': '0',
#                                            'transporta': {'CNPJ': '27807598000181',
#                                                           'IE': '87418103',
#                                                           'UF': 'RJ',
#                                                           'xEnder': 'Rua '
#                                                                     'Vieira '
#                                                                     'Ferreira, '
#                                                                     '114',
#                                                           'xMun': 'Rio de '
#                                                                   'Janeiro',
#                                                           'xNome': 'Yellow '
#                                                                    'Log'},
#                                            'vol': {'pesoB': '2.600',
#                                                    'pesoL': '2.600',
#                                                    'qVol': '1'}}}},
#              'protNFe': {'@versao': '4.00',
#                          'infProt': {'cStat': '100',
#                                      'chNFe': '35211136882195000279550010000028561541212336',
#                                      'dhRecbto': '2021-11-04T16:46:25-03:00',
#                                      'digVal': 'YmPqwgaLfoagMFaaL8rLNhtAI=',
#                                      'nProt': '135211306234123',
#                                      'tpAmb': '1',
#                                      'verAplic': 'SP_NFE_PL009_V4',
#                                      'xMotivo': 'Autorizado o uso da NF-e'}}}}

# %%
# Coletar informações de notas fiscais no padrão DANFE e guardar em uma função:
def ler_xml_danfe(nota_fiscal):
    
    with open(f'{nota_fiscal}', 'rb') as arquivo:
        documento = xmltodict.parse(arquivo)

    dict_nota_fiscal = documento['nfeProc']['NFe']['infNFe']

    def coletar_cpf_cnpj(nota, pessoa = 'dest'):
        try:
            return nota[pessoa]['CPF']
        except:
            return nota[pessoa]['CNPJ']


    valor_total = dict_nota_fiscal['total']['ICMSTot']['vProd']
    valor_nota_fiscal = dict_nota_fiscal['total']['ICMSTot']['vNF']
    total_desconto = dict_nota_fiscal['total']['ICMSTot']['vDesc']
    cnpj_cpf_vendeu = coletar_cpf_cnpj(dict_nota_fiscal, pessoa = 'emit')
    nome_vendeu = dict_nota_fiscal['emit']['xNome']
    cpf_cnpj_comprou = coletar_cpf_cnpj(dict_nota_fiscal)
    nome_comprou = dict_nota_fiscal['dest']['xNome']
    produtos = dict_nota_fiscal['det']
    lista_produtos = []

    for produto in produtos:
        nome_produto = produto['prod']['xProd']
        valor_produto = produto['prod']['vProd']
        lista_produtos.append((nome_produto, valor_produto))

    resposta = {'Tipo': 'Produto',
               'Total R$': float(valor_total),
               'Desconto Total R$': float(total_desconto),
               'Total da Nota Fiscal R$': float(valor_nota_fiscal),
               'CPF/CNPJ vendedor': cnpj_cpf_vendeu,
               'Nome vendedor': nome_vendeu,
               'CPF/CNPJ comprador': cpf_cnpj_comprou,
               'Nome comprador': nome_comprou,
               'Lista de Produtos/Serviços': lista_produtos}

    return resposta

# %%
# Coletar informações de notas fiscais no padrão Nota carioca e guardar em uma função:
def ler_notafiscal_servico(nota_fiscal):
    
    with open(f'{nota_fiscal}', 'rb') as arquivo:
        documento = xmltodict.parse(arquivo)

    dict_nota_fiscal = documento['ConsultarNfseResposta']['ListaNfse']['CompNfse']['Nfse']['InfNfse']

    def coletar_cpf_cnpj(nota, pessoa = 'Tomador'):
        try:
            return nota[pessoa+'Servico']['Identificacao'+pessoa]['CpfCnpj']['Cnpj']
        except:
            return nota[pessoa+'Servico']['Identificacao'+pessoa]['CpfCnpj']['Cpf']


    valor_total = dict_nota_fiscal['Servico']['Valores']['ValorServicos']
    valor_nota_fiscal = dict_nota_fiscal['Servico']['Valores']['ValorLiquidoNfse']
    total_desconto = float(valor_total) - float(valor_nota_fiscal)
    cnpj_vendeu = dict_nota_fiscal['PrestadorServico']['IdentificacaoPrestador']['Cnpj']
    nome_vendeu = dict_nota_fiscal['PrestadorServico']['RazaoSocial']
    cpf_cnpj_comprou = coletar_cpf_cnpj(dict_nota_fiscal)
    nome_comprou = dict_nota_fiscal['TomadorServico']['RazaoSocial']
    servico = dict_nota_fiscal['Servico']['Discriminacao']

    resposta = {'Tipo': 'Serviço',
               'Total R$': float(valor_total),
               'Desconto Total R$': float(total_desconto),
               'Total da Nota Fiscal R$': float(valor_nota_fiscal),
               'CPF/CNPJ vendedor': cnpj_cpf_vendeu,
               'Nome vendedor': nome_vendeu,
               'CPF/CNPJ comprador': cpf_cnpj_comprou,
               'Nome comprador': nome_comprou,
               'Lista de Produtos/Serviços': [servico]}

    return resposta

# %%
# Listar os arquivos que estão na pasta e usar para percorrer toda a pasta em busca de notas fiscais no padrão 
#definido

lista_arquivos = os.listdir('NFs Finais')

lista_notas_fiscais = []
for arquivo in lista_arquivos:
    if '.xml' in arquivo:
        if 'DANFE' in arquivo:
            lista_notas_fiscais.append(ler_xml_danfe(f'NFs Finais/{arquivo}'))
    
        else: 
            lista_notas_fiscais.append(ler_notafiscal_servico(f'NFs Finais/{arquivo}'))

# %%
#Colocar em um dataframe as informações das notas fiscais para criar uma base de dados de notas fiscais:
df_notas_fiscais = pd.DataFrame.from_records(lista_notas_fiscais)
df_notas_fiscais
# Out:
#       Tipo  Total R$  Desconto Total R$  Total da Nota Fiscal R$  \
# 0  Produto    449.00               75.0                   374.17
# 1  Produto    769.17                0.0                   849.00
# 2  Serviço   4500.00                0.0                  4500.00
#
#   CPF/CNPJ vendedor                           Nome vendedor  \
# 0    36882195000279  BROTA COMPANY COMERCIO DE PLANTAS LTDA
# 1    60409075055054                      NESTLE BRASIL LTDA
# 2    36882195000279                      LIRA BOLADO NO XML
#
#   CPF/CNPJ comprador             Nome comprador  \
# 0        10000000000            Lira da Hashtag
# 1        11122233344            Lira da Hashtag
# 2     26344392000108  HASHTAG TREINAMENTOS LTDA
#
#                           Lista de Produtos/Serviços
# 0  [(b.box led, 389.00), (Tomilho Serpilho, 10.00...
# 1  [(ESSENZA Mini C30 Metal 110V, 534.82), (NOMAD...
# 2  [Nota referente aos serviços realizados no mês...

# %% [markdown]
# * OBS: Quando acontece dos valores da coluna: "Total RS" serem menores que o da coluna: "Total da Nota Fiscal RS", significa que houve impostos sobre o total, acarretando no final ao total da nota fiscal um valor mais alto;

# %%
df_notas_fiscais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Tipo                        3 non-null      object
#  1   Total R$                    3 non-null      float64
#  2   Desconto Total R$           3 non-null      float64
#  3   Total da Nota Fiscal R$     3 non-null      float64
#  4   CPF/CNPJ vendedor           3 non-null      object
#  5   Nome vendedor               3 non-null      object
#  6   CPF/CNPJ comprador          3 non-null      object
#  7   Nome comprador              3 non-null      object
#  8   Lista de Produtos/Serviços  3 non-null      object
# dtypes: float64(3), object(6)
# memory usage: 344.0+ bytes
